# %%
import pandas as pd

# %% [markdown]
# ## Birth Rates

# %%
birth_rate = pd.read_csv('../data/raw/birth_rate.csv', index_col=1)
birth_rate = birth_rate.drop(['Country Name', 'Indicator Name', 'Indicator Code', '2017', 'Unnamed: 62'], axis=1)
birth_rate = birth_rate.dropna().T
list(birth_rate)
# Out:
# ['ABW',
#  'AFG',
#  'AGO',
#  'ALB',
#  'ARB',
#  'ARE',
#  'ARG',
#  'ARM',
#  'ATG',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BDI',
#  'BEL',
#  'BEN',
#  'BFA',
#  'BGD',
#  'BGR',
#  'BHR',
#  'BHS',
#  'BIH',
#  'BLR',
#  'BLZ',
#  'BOL',
#  'BRA',
#  'BRB',
#  'BRN',
#  'BTN',
#  'BWA',
#  'CAF',
#  'CAN',
#  'CEB',
#  'CHE',
#  'CHI',
#  'CHL',
#  'CHN',
#  'CIV',
#  'CMR',
#  'COD',
#  'COG',
#  'COL',
#  'COM',
#  'CPV',
#  'CRI',
#  'CSS',
#  'CUB',
#  'CYP',
#  'CZE',
#  'DEU',
#  'DJI',
#  'DNK',
#  'DOM',
#  'DZA',
#  'EAP',
#  'EAR',
#  'EAS',
#  'ECA',
#  'ECS',
#  'ECU',
#  'EGY',
#  'EMU',
#  'ERI',
#  'ESP',
#  'EST',
#  'ETH',
#  'EUU',
#  'FCS',
#  'FIN',
#  'FJI',
#  'FRA',
#  'FSM',
#  'GAB',
#  'GBR',
#  'GEO',
#  'GHA',
#  'GIN',
#  'GMB',
#  'GNB',
#  'GNQ',
#  'GRC',
#  'GRD',
#  'GTM',
#  'GUM',
#  'GUY',
#  'HIC',
#  'HKG',
#  'HND',
#  'HPC',
#  'HRV',
#  'HTI',
#  'HUN',
#  'IBD',
#  'IBT',
#  'IDA',
#  'IDB',
#  'IDN',
#  'IDX',
#  'IND',
#  'IRL',
#  'IRN',
# ...

# %% [markdown]
# ## Arable Land (Percent)

# %%
arable_land = pd.read_csv('../data/raw/arable_land_percent.csv', index_col=1)
arable_land = arable_land.drop(['Country Name', 'Indicator Name', 'Indicator Code', '2016', '2017', 'Unnamed: 62', '1960'], axis=1)
arable_land = arable_land.dropna().T
arable_land.head()
# Out:
# Country Code        ABW        AFG       AGO        ALB      AND       ARB  \
# 1961          11.111111  11.717673  2.141654  15.766423  2.12766  3.382112
# 1962          11.111111  11.794259  2.165717  15.912409  2.12766  3.383727
# 1963          11.111111  11.870845  2.181760  16.058394  2.12766  3.400462
# 1964          11.111111  11.947431  2.205823  16.167883  2.12766  3.428281
# 1965          11.111111  11.947431  2.221866  16.788321  2.12766  3.462338
#
# Country Code       ARE       ARG  ASM        ATG    ...          VGB  \
# 1961          0.059809  6.795435  5.0  18.181818    ...     6.666667
# 1962          0.059809  7.008466  5.0  15.909091    ...     6.666667
# 1963          0.059809  7.161936  5.0  18.181818    ...     6.666667
# 1964          0.059809  7.308098  5.0  15.909091    ...     6.666667
# 1965          0.059809  7.476550  5.0  18.181818    ...     6.666667
#
# Country Code        VIR        VNM       VUT       WLD       WSM       YEM  \
# ...

# %% [markdown]
# ## Arable Land (Per Person)

# %%
arable_pp = pd.read_csv('../data/raw/arable_land_per_person.csv', index_col=1)
arable_pp = arable_pp.drop(['Country Name', 'Indicator Name', 'Indicator Code', '2016', '2017', 'Unnamed: 62', '1960'], axis=1)
arable_pp = arable_pp.dropna().T
arable_pp.head()
# Out:
# Country Code        ABW        AFG       AGO        ALB      AND       ARB  \
# 1961          11.111111  11.717673  2.141654  15.766423  2.12766  3.382112
# 1962          11.111111  11.794259  2.165717  15.912409  2.12766  3.383727
# 1963          11.111111  11.870845  2.181760  16.058394  2.12766  3.400462
# 1964          11.111111  11.947431  2.205823  16.167883  2.12766  3.428281
# 1965          11.111111  11.947431  2.221866  16.788321  2.12766  3.462338
#
# Country Code       ARE       ARG  ASM        ATG    ...          VGB  \
# 1961          0.059809  6.795435  5.0  18.181818    ...     6.666667
# 1962          0.059809  7.008466  5.0  15.909091    ...     6.666667
# 1963          0.059809  7.161936  5.0  18.181818    ...     6.666667
# 1964          0.059809  7.308098  5.0  15.909091    ...     6.666667
# 1965          0.059809  7.476550  5.0  18.181818    ...     6.666667
#
# Country Code        VIR        VNM       VUT       WLD       WSM       YEM  \
# ...

# %% [markdown]
# ## Birth Life Expectancy

# %%
birth_le = pd.read_csv('../data/raw/birth_life_expectancy.csv', index_col=1)
birth_le = birth_le.drop(['Country Name', 'Indicator Name', 'Indicator Code', '2017', 'Unnamed: 62'], axis=1)
birth_le = birth_le.dropna().T
birth_le.head()
# Out:
# Country Code     ABW     AFG     AGO     ALB        ARB     ARE     ARG  \
# 1960          65.662  32.292  33.251  62.279  46.825065  52.265  65.022
# 1961          66.074  32.742  33.573  63.298  47.407699  53.312  65.141
# 1962          66.444  33.185  33.914  64.187  47.988878  54.349  65.233
# 1963          66.787  33.624  34.272  64.911  48.572229  55.375  65.311
# 1964          67.113  34.060  34.645  65.461  49.159167  56.385  65.388
#
# Country Code     ARM     ATG        AUS   ...       VEN        VIR     VNM  \
# 1960          65.971  62.115  70.817073   ...    59.253  66.224854  59.041
# 1961          66.402  62.555  70.973171   ...    59.829  66.487976  59.722
# 1962          66.837  62.979  70.942439   ...    60.395  66.741098  60.391
# 1963          67.276  63.385  70.911707   ...    60.948  66.996220  61.024
# 1964          67.715  63.774  70.880976   ...    61.488  67.260366  61.585
#
# Country Code     VUT        WLD     WSM     YEM     ZAF     ZMB     ZWE
# ...

# %% [markdown]
# ## CO2 Emissions

# %%
co2_em = pd.read_csv('../data/raw/co2_emission.csv', index_col=1)
co2_em = co2_em.drop(['Country Name', 'Indicator Name', 'Indicator Code', '2015', '2016', '2017', 'Unnamed: 62'], axis=1)
co2_em = co2_em.dropna().T
co2_em.head()
# Out:
# Country Code       AFG       AGO       ALB       ARB       ARE       ARG  \
# 1960          0.046060  0.097472  1.258195  0.643689  0.118758  2.367473
# 1961          0.053604  0.079038  1.374186  0.685151  0.108837  2.442616
# 1962          0.073765  0.201289  1.439956  0.760855  0.163018  2.522392
# 1963          0.074233  0.192535  1.181681  0.874941  0.175223  2.316356
# 1964          0.086292  0.201003  1.111742  0.999098  0.132355  2.538379
#
# Country Code       ATG       AUS       AUT        BEL    ...          UMC  \
# 1960          0.662643  8.582937  4.373319   9.941594    ...     1.682250
# 1961          0.849084  8.641569  4.496362  10.103872    ...     1.385467
# 1962          1.796794  8.835688  4.755362  10.641190    ...     1.260818
# 1963          1.446821  9.226440  5.155194  11.386929    ...     1.262008
# 1964          1.540135  9.759073  5.391004  11.053655    ...     1.294995
#
# Country Code       URY        USA       VCT       VEN       VNM       WLD  \
# ...

# %% [markdown]
# ## Death Rates

# %%
# Fix Comma Delimitation
death_raw = open('../data/raw/death_rate.csv', 'r').read().replace('rate,', 'rate').replace('1,000', '1000')
out = open('../data/raw/death_rate.csv', 'w')
out.write(death_raw)
out.close()

# %%
death_rates = pd.read_csv('../data/raw/death_rate.csv', index_col=1)
death_rates = death_rates.drop(['Country Name', 'Indicator Name', 'Indicator Code', '2017', 'Unnamed: 62'], axis=1)
death_rates = death_rates.dropna().T
death_rates.head()
# Out:
# Country Code    ABW     AFG     AGO     ALB        ARB     ARE    ARG    ARM  \
# 1960          6.388  32.396  32.293  11.328  19.854202  15.150  8.637  9.647
# 1961          6.241  31.898  31.813  10.720  19.384555  14.196  8.689  9.250
# 1962          6.118  31.414  31.313  10.176  18.920558  13.252  8.752  8.838
# 1963          6.012  30.938  30.800   9.708  18.457337  12.330  8.821  8.420
# 1964          5.920  30.467  30.282   9.321  17.992546  11.440  8.889  8.006
#
# Country Code    ATG  AUS   ...       VEN    VIR     VNM     VUT        WLD  \
# 1960          9.136  8.6   ...    10.017  10.00  12.044  18.312  17.741428
# 1961          8.970  8.5   ...     9.721   9.68  11.658  17.781  15.023582
# 1962          8.799  8.7   ...     9.419   9.36  11.271  17.250  13.972581
# 1963          8.618  8.7   ...     9.111   9.04  10.897  16.719  13.749269
# 1964          8.426  9.0   ...     8.798   8.72  10.561  16.193  13.797060
#
# ...

# %% [markdown]
# ## Mortality Rate (Female)

# %%
# Fix Comma Delimitation
mor_fem_raw = open('../data/raw/mortality_adult_female.csv', 'r').read().replace('rate,', 'rate').replace('adult,', 'adult').replace('1,000', '1000')
out = open('../data/raw/mortality_adult_female.csv', 'w')
out.write(mor_fem_raw)
out.close()

# %%
mor_fem = pd.read_csv('../data/raw/mortality_adult_female.csv', index_col=1)
mor_fem = mor_fem.drop(['Country Name', 'Indicator Name', 'Indicator Code', '2017', 'Unnamed: 62'], axis=1)
mor_fem = mor_fem.dropna().T
mor_fem.head()
# Out:
# Country Code      ABW      AFG      AGO      ALB         ARB      ARE  \
# 1960          181.484  551.122  498.232  151.058  298.731957  253.996
# 1961          175.849  545.510  494.482  139.856  294.941374  246.851
# 1962          170.213  539.898  490.731  128.654  290.919198  239.707
# 1963          166.562  534.645  486.126  129.676  286.005384  233.785
# 1964          162.911  529.392  481.521  130.698  281.160519  227.863
#
# Country Code      ARG      ARM      ATG     AZE   ...         VEN      VIR  \
# 1960          156.247  136.917  244.924  92.807   ...     250.124  174.747
# 1961          151.895  131.925  241.326  93.540   ...     243.292  171.937
# 1962          147.544  126.933  237.728  94.272   ...     236.460  169.127
# 1963          146.334  123.152  234.223  95.001   ...     229.642  166.008
# 1964          145.124  119.371  230.719  95.730   ...     222.825  162.888
#
# Country Code      VNM      VUT         WLD      WSM      YEM      ZAF  \
# ...

# %% [markdown]
# ## Mortality Rate (Male)

# %%
# Fix Comma Delimitation
mor_mal_raw = open('../data/raw/mortality_adult_male.csv', 'r').read().replace('rate,', 'rate').replace('adult,', 'adult').replace('1,000', '1000')
out = open('../data/raw/mortality_adult_male.csv', 'w')
out.write(mor_mal_raw)
out.close()

# %%
mor_mal = pd.read_csv('../data/raw/mortality_adult_male.csv', index_col=1)
mor_mal = mor_mal.drop(['Country Name', 'Indicator Name', 'Indicator Code', '2017', 'Unnamed: 62'], axis=1)
mor_mal = mor_mal.dropna().T
mor_mal.head()
# Out:
# Country Code      ABW      AFG      AGO      ALB         ARB      ARE  \
# 1960          227.253  604.597  561.897  160.480  359.314690  328.373
# 1961          223.170  598.908  558.226  150.942  354.800418  318.924
# 1962          219.087  593.219  554.556  141.405  350.206135  309.474
# 1963          215.330  587.752  549.975  143.060  345.429613  301.397
# 1964          211.574  582.284  545.395  144.716  340.651254  293.320
#
# Country Code      ARG      ARM      ATG      AZE   ...         VEN      VIR  \
# 1960          255.108  225.671  275.552  221.357   ...     304.487  219.681
# 1961          252.663  219.648  272.245  221.348   ...     298.528  216.516
# 1962          250.219  213.626  268.938  221.340   ...     292.569  213.350
# 1963          250.998  208.400  266.171  221.330   ...     288.324  209.788
# 1964          251.778  203.175  263.405  221.321   ...     284.078  206.226
#
# Country Code      VNM      VUT         WLD      WSM      YEM      ZAF  \
# ...

# %% [markdown]
# ## Mortality Rate (Infants)

# %%
# Fix Comma Delimitation
mor_inf_raw = open('../data/raw/mortality_rate_infant.csv', 'r').read().replace('rate,', 'rate').replace('1,000', '1000')
out = open('../data/raw/mortality_rate_infant.csv', 'w')
out.write(mor_inf_raw)
out.close()

# %%
mor_inf = pd.read_csv('../data/raw/mortality_rate_infant.csv', index_col=1)
mor_inf = mor_inf.drop(['Country Name', 'Indicator Name', 'Indicator Code', '2017', 'Unnamed: 62'], axis=1)
mor_inf = mor_inf.dropna().T
mor_inf.head()
# Out:
# Country Code    AFG    ARE   AUS   AUT   BEL    BEN    BFA    BGD    BHR  \
# 1960          240.5  134.4  20.3  37.2  29.5  191.4  155.3  172.9  134.4
# 1961          236.2  128.4  19.9  35.0  28.1  188.1  153.7  168.6  123.7
# 1962          232.2  122.2  19.5  32.9  27.0  184.3  152.2  164.7  113.8
# 1963          228.3  116.1  19.1  31.2  26.0  180.1  150.8  161.1  104.8
# 1964          224.6  109.9  18.7  29.6  25.0  175.6  149.5  157.9   96.2
#
# Country Code    BOL  ...    TTO    TUR    TZA    UGA   URY   USA   VEN    VUT  \
# 1960          174.4  ...   55.5  172.6  143.2  131.5  57.7  25.9  58.9  105.6
# 1961          171.3  ...   53.9  167.3  141.9  128.9  56.5  25.4  57.2  103.2
# 1962          168.2  ...   52.2  161.9  140.4  126.5  55.0  24.9  55.7  100.6
# 1963          165.1  ...   50.7  156.5  138.9  124.2  53.6  24.3  54.5   97.8
# 1964          162.0  ...   49.3  151.5  137.3  122.0  52.7  23.8  53.4   94.9
#
# Country Code    ZMB   ZWE
# 1960          122.2  92.5
# ...

# %% [markdown]
# ## Mortality Rate (Under 5)

# %%
# Fix Comma Delimitation
mor_u5_raw = open('../data/raw/mortality_rate_under_5.csv', 'r').read().replace('rate,', 'rate').replace('1,000', '1000')
out = open('../data/raw/mortality_rate_under_5.csv', 'w')
out.write(mor_u5_raw)
out.close()

# %%
mor_u5 = pd.read_csv('../data/raw/mortality_rate_under_5.csv', index_col=1)
mor_u5 = mor_u5.drop(['Country Name', 'Indicator Name', 'Indicator Code', '2017', 'Unnamed: 62'], axis=1)
mor_u5 = mor_u5.dropna().T
mor_u5.head()
# Out:
# Country Code    AFG    ARE   AUS   AUT   BEL    BEN    BFA    BGD    BHR  \
# 1960          356.5  199.9  24.9  42.8  33.9  321.2  342.0  259.2  200.0
# 1961          350.5  190.4  24.3  40.2  32.4  315.9  338.0  252.8  182.9
# 1962          344.8  180.6  23.7  37.9  31.1  309.9  334.3  247.0  166.8
# 1963          339.3  170.6  23.2  35.9  30.0  303.1  330.8  241.6  152.0
# 1964          334.1  160.4  22.7  34.2  28.9  295.7  327.6  236.7  138.3
#
# Country Code    BOL  ...     TTO    TUR    TZA    UGA   URY   USA   VEN  \
# 1960          289.1  ...    67.1  258.7  242.3  222.6  64.0  30.1  79.5
# 1961          283.0  ...    64.8  250.8  240.1  217.8  62.6  29.5  76.8
# 1962          277.0  ...    62.6  242.8  237.6  213.5  61.0  28.9  74.4
# 1963          271.1  ...    60.6  234.7  235.0  209.4  59.6  28.3  72.5
# 1964          265.1  ...    58.7  227.1  232.3  205.4  58.6  27.7  70.8
#
# Country Code    VUT    ZMB    ZWE
# 1960          153.4  205.7  150.4
# ...

# %% [markdown]
# ## Net Official Development Assistance Recieved

# %%
dev_ass = pd.read_csv('../data/raw/net_official_dev_assistance_received.csv', index_col=1)
dev_ass = dev_ass.drop(['Country Name', 'Indicator Name', 'Indicator Code', '2017', 'Unnamed: 62'], axis=1)
dev_ass = dev_ass.dropna().T
dev_ass.head()
# Out:
# Country Code         AFG          ARB         ARG         BDI         BEN  \
# 1960          17180000.0  881990000.0  28580000.0   7530000.0     20000.0
# 1961          34670000.0  973930000.0  29180000.0   7190000.0   1480000.0
# 1962          16930000.0  929090000.0  39800000.0  11070000.0   3750000.0
# 1963          36670000.0  858610000.0  37800000.0   6160000.0   4260000.0
# 1964          46170000.0  831420000.0  17220000.0   8090000.0  18070000.0
#
# Country Code         BFA        BLZ         BOL          BRA        BWA  \
# 1960            200000.0  1820000.0  12080000.0   24110000.0  3430000.0
# 1961           1350000.0  2820000.0  23630000.0  266570000.0  5460000.0
# 1962           4430000.0  5520000.0  35910000.0  166560000.0  5240000.0
# 1963           4140000.0  4060000.0  53500000.0  197240000.0  5330000.0
# 1964          15400000.0  1550000.0  40920000.0  249000000.0  8870000.0
#
# Country Code     ...             TZA         UGA           UMC         URY  \
# ...

# %% [markdown]
# ## Population Growth

# %%
pop_growth = pd.read_csv('../data/raw/population_growth.csv', index_col=1)
pop_growth = pop_growth.drop(['Country Name', 'Indicator Name', 'Indicator Code', 'Unnamed: 62'], axis=1)
pop_growth = pop_growth.dropna().T
pop_growth.head()
# Out:
# Country Code       ABW       AFG       AGO       ALB       AND        ARE  \
# 1960          3.148037  1.816077  1.903517  3.015423  7.050663   5.859584
# 1961          2.238144  1.876528  1.927754  3.120855  6.941532   8.723625
# 1962          1.409622  1.934999  1.945774  3.056731  6.692697  10.681181
# 1963          0.832453  1.992521  1.930693  2.953749  6.559522  11.012721
# 1964          0.592649  2.049423  1.870296  2.880686  6.241511   9.824817
#
# Country Code       ARG       ARM       ASM       ATG    ...          VGB  \
# 1960          1.630874  3.596386  1.403903  1.121208    ...     1.265285
# 1961          1.606889  3.531702  2.335966  1.444191    ...     1.507318
# 1962          1.584309  3.444264  3.033668  1.765458    ...     1.738329
# 1963          1.557532  3.330247  3.558598  1.992477    ...     1.838858
# 1964          1.524221  3.193727  3.661243  2.088042    ...     2.049372
#
# Country Code        VIR       VNM       VUT       WSM       XKX       YEM  \
# ...

# %% [markdown]
# ## Population Total

# %%
# Fix Comma Delimitation
pop_tot_raw = open('../data/raw/population_total.csv', 'r').read().replace('Population,', 'Population')
out = open('../data/raw/population_total.csv', 'w')
out.write(pop_tot_raw)
out.close()

# %%
pop_total = pd.read_csv('../data/raw/population_total.csv', index_col=1)
pop_total = pop_total.drop(['Country Name', 'Indicator Name', 'Indicator Code', 'Unnamed: 62'], axis=1)
pop_total = pop_total.dropna().T
pop_total.head()
# Out:
# Country Code      ABW        AFG        AGO        ALB      AND          ARB  \
# 1960          54211.0  8996351.0  5643182.0  1608800.0  13411.0   92490932.0
# 1961          55438.0  9166764.0  5753024.0  1659800.0  14375.0   95044497.0
# 1962          56225.0  9345868.0  5866061.0  1711319.0  15370.0   97682294.0
# 1963          56695.0  9533954.0  5980417.0  1762621.0  16412.0  100411076.0
# 1964          57032.0  9731361.0  6093321.0  1814135.0  17469.0  103239902.0
#
# Country Code       ARE         ARG        ARM      ASM    ...          VIR  \
# 1960           92634.0  20619075.0  1874120.0  20013.0    ...      32500.0
# 1961          101078.0  20953077.0  1941491.0  20486.0    ...      34300.0
# 1962          112472.0  21287682.0  2009526.0  21117.0    ...      35000.0
# 1963          125566.0  21621840.0  2077575.0  21882.0    ...      39800.0
# 1964          138529.0  21953929.0  2144998.0  22698.0    ...      40800.0
#
# ...

# %% [markdown]
# ## Rural Population (Percentage)

# %%
rural_per = pd.read_csv('../data/raw/rural_pop_percent.csv', index_col=1)
rural_per = rural_per.drop(['Country Name', 'Indicator Name', 'Indicator Code', 'Unnamed: 62'], axis=1)
rural_per = rural_per.dropna().T
rural_per.head()
# Out:
# Country Code     ABW     AFG     AGO     ALB     AND        ARB     ARE  \
# 1960          49.224  91.599  89.565  69.295  41.550  68.708026  26.500
# 1961          49.239  91.316  89.202  69.057  39.017  67.965580  25.617
# 1962          49.254  91.024  88.796  68.985  36.538  67.219820  24.752
# 1963          49.270  90.724  88.376  68.914  34.128  66.450960  23.907
# 1964          49.285  90.414  87.942  68.842  31.795  65.652964  23.081
#
# Country Code     ARG     ARM     ASM   ...       VGB     VIR     VNM     VUT  \
# 1960          26.389  48.725  33.789   ...    87.772  43.523  85.300  89.596
# 1961          25.783  47.853  33.359   ...    87.382  42.136  84.969  89.417
# 1962          25.233  46.981  32.932   ...    86.981  40.759  84.631  89.235
# 1963          24.691  46.111  32.507   ...    86.570  39.396  84.286  89.050
# 1964          24.156  45.242  32.084   ...    86.146  38.048  83.936  88.862
#
# Country Code        WLD     WSM     YEM     ZAF     ZMB     ZWE
# ...

# %% [markdown]
# ## Survival Female

# %%
# Fix Comma Delimitation
sur_fem = open('../data/raw/survival_female_65.csv', 'r').read().replace('65,', '65')
out = open('../data/raw/survival_female_65.csv', 'w')
out.write(sur_fem)
out.close()

# %%
sur_fem = pd.read_csv('../data/raw/survival_female_65.csv', index_col=1)
sur_fem = sur_fem.drop(['Country Name', 'Indicator Name', 'Indicator Code', '2017', 'Unnamed: 62'], axis=1)
sur_fem = sur_fem.dropna().T
sur_fem.head()
# Out:
# Country Code       ABW       AFG       AGO       ALB        ARB      ARE  \
# 1960          69.91539  21.20095  24.60123  68.06445  44.810465  53.7530
# 1961          70.81053  21.73633  24.99663  69.86953  45.531914  55.0040
# 1962          71.70567  22.27172  25.39202  71.67461  46.263062  56.2550
# 1963          72.28395  22.80175  25.89918  71.99951  47.089901  57.4532
# 1964          72.86223  23.33178  26.40634  72.32442  47.915023  58.6514
#
# Country Code      ARG       ARM       ATG       AUS    ...          VEN  \
# 1960          71.8846  73.38391  61.76661  80.40144    ...     58.13828
# 1961          72.4258  74.08382  62.42447  80.54434    ...     59.15199
# 1962          72.9670  74.78373  63.08232  80.68724    ...     60.16571
# 1963          73.2326  75.37616  63.70763  80.67864    ...     61.19547
# 1964          73.4982  75.96859  64.33295  80.67004    ...     62.22523
#
# Country Code       VIR       VNM       VUT        WLD       WSM       YEM  \
# ...

# %% [markdown]
# ## Urban Population Percent

# %%
urb_per = pd.read_csv('../data/raw/urban_pop_percent.csv', index_col=1)
urb_per = urb_per.drop(['Country Name', 'Indicator Name', 'Indicator Code', 'Unnamed: 62'], axis=1)
urb_per = urb_per.dropna().T
urb_per.head()
# Out:
# Country Code     ABW    AFG     AGO     ALB     AND        ARB     ARE  \
# 1960          50.776  8.401  10.435  30.705  58.450  31.291974  73.500
# 1961          50.761  8.684  10.798  30.943  60.983  32.034420  74.383
# 1962          50.746  8.976  11.204  31.015  63.462  32.780180  75.248
# 1963          50.730  9.276  11.624  31.086  65.872  33.549040  76.093
# 1964          50.715  9.586  12.058  31.158  68.205  34.347036  76.919
#
# Country Code     ARG     ARM     ASM   ...       VGB     VIR     VNM     VUT  \
# 1960          73.611  51.275  66.211   ...    12.228  56.477  14.700  10.404
# 1961          74.217  52.147  66.641   ...    12.618  57.864  15.031  10.583
# 1962          74.767  53.019  67.068   ...    13.019  59.241  15.369  10.765
# 1963          75.309  53.889  67.493   ...    13.430  60.604  15.714  10.950
# 1964          75.844  54.758  67.916   ...    13.854  61.952  16.064  11.138
#
# Country Code        WLD     WSM     YEM     ZAF     ZMB     ZWE
# ...

# %%
country = set(list(birth_rate)).intersection(
                                   # set(list(birth_le)), 
                                   # set(list(co2_em)), 
                                   # set(list(death_rates)), 
                                   # set(list(mor_fem)),
                                   # set(list(mor_mal)),
                                   # set(list(mor_inf)),
                                   # set(list(mor_u5)),
                                   # set(list(dev_ass)),
                                   # set(list(pop_total)),
                                   # set(list(pop_growth)),
                                   # set(list(rural_per)),
                                   # set(list(sur_fem)),
                                   # set(list(urb_per))
                               ) 

# print(sorted(country))
